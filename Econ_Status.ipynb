# %%
#Import dependencies
import pandas as pd

# %%
ELA_data = "2013-2019_ELA_Test_Results_District.xlsx"

Econstatus_df = pd.read_excel(ELA_data, 'Econ Status')

# %%
Econstatus_df
# Out:
#       District       Grade  Year         Category  Number Tested  \
# 0            1           3  2013      Econ Disadv            615
# 1            1           3  2014      Econ Disadv            594
# 2            1           3  2015      Econ Disadv            467
# 3            1           3  2016      Econ Disadv            459
# 4            1           3  2017      Econ Disadv            456
# ...        ...         ...   ...              ...            ...
# 3131        32  All Grades  2015  Not Econ Disadv            915
# 3132        32  All Grades  2016  Not Econ Disadv            922
# 3133        32  All Grades  2017  Not Econ Disadv            860
# 3134        32  All Grades  2018  Not Econ Disadv            537
# 3135        32  All Grades  2019  Not Econ Disadv            581
#
#       Mean Scale Score  # Level 1  % Level 1  # Level 2  % Level 2  # Level 3  \
# 0           292.159363        278  45.203251        207  33.658535        116
# ...

# %%
clean1_df_Econstatus=Econstatus_df[Econstatus_df.Year==2019]

# %%
clean1_df_Econstatus
# Out:
#       District       Grade  Year         Category  Number Tested  \
# 6            1           3  2019      Econ Disadv            410
# 13           1           4  2019      Econ Disadv            427
# 20           1           5  2019      Econ Disadv            445
# 27           1           6  2019      Econ Disadv            436
# 34           1           7  2019      Econ Disadv            472
# ...        ...         ...   ...              ...            ...
# 3107        32           5  2019  Not Econ Disadv             92
# 3114        32           6  2019  Not Econ Disadv            114
# 3121        32           7  2019  Not Econ Disadv            118
# 3128        32           8  2019  Not Econ Disadv            118
# 3135        32  All Grades  2019  Not Econ Disadv            581
#
#       Mean Scale Score  # Level 1  % Level 1  # Level 2  % Level 2  # Level 3  \
# 6           598.590271         46  11.219512        178  43.414635        159
# ...

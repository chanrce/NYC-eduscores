# %%
#Import dependencies
import pandas as pd

# %%
ELA_data = "2013-2019_ELA_Test_Results_District.xlsx"

ELL_df = pd.read_excel(ELA_data, 'ELL')

# %%
ELL_df
# Out:
#       District       Grade  Year     Category  Number Tested  \
# 0            1           3  2014  Current ELL             59
# 1            1           3  2015  Current ELL             50
# 2            1           3  2016  Current ELL             47
# 3            1           3  2017  Current ELL             53
# 4            1           3  2018  Current ELL             77
# ...        ...         ...   ...          ...            ...
# 4027        32  All Grades  2015    Never ELL           4378
# 4028        32  All Grades  2016    Never ELL           4150
# 4029        32  All Grades  2017    Never ELL           3955
# 4030        32  All Grades  2018    Never ELL           3668
# 4031        32  All Grades  2019    Never ELL           3523
#
#       Mean Scale Score  # Level 1  % Level 1  # Level 2  % Level 2  # Level 3  \
# 0           271.440674         40  67.796608         13  22.033897          6
# ...

# %%
clean1_df_ELL=ELL_df[ELL_df.Year==2019]

# %%
clean1_df_ELL
# Out:
#       District       Grade  Year     Category  Number Tested  \
# 5            1           3  2019  Current ELL             42
# 11           1           4  2019  Current ELL             46
# 17           1           5  2019  Current ELL             28
# 23           1           6  2019  Current ELL             33
# 29           1           7  2019  Current ELL             30
# ...        ...         ...   ...          ...            ...
# 4007        32           5  2019    Never ELL            590
# 4013        32           6  2019    Never ELL            692
# 4019        32           7  2019    Never ELL            635
# 4025        32           8  2019    Never ELL            642
# 4031        32  All Grades  2019    Never ELL           3523
#
#       Mean Scale Score  # Level 1  % Level 1  # Level 2  % Level 2  # Level 3  \
# 5           588.666687         13  30.952381         18  42.857143         11
# ...

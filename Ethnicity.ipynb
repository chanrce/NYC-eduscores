# %%
#Import dependencies
import pandas as pd

# %%
ELA_data = "2013-2019_ELA_Test_Results_District.xlsx"

Ethnicity_df = pd.read_excel(ELA_data, 'Ethnicity')

# %%
Ethnicity_df
# Out:
#       District       Grade  Year Category  Number Tested Mean Scale Score  \
# 0            1           3  2013    Asian            191           320.01
# 1            1           3  2014    Asian            180          316.228
# 2            1           3  2015    Asian            184          317.201
# 3            1           3  2016    Asian            174          329.799
# 4            1           3  2017    Asian            145          327.531
# ...        ...         ...   ...      ...            ...              ...
# 6267        32  All Grades  2015    White            120          290.733
# 6268        32  All Grades  2016    White            103          299.184
# 6269        32  All Grades  2017    White            111          303.514
# 6270        32  All Grades  2018    White            126          597.286
# 6271        32  All Grades  2019    White            126          600.468
#
#      # Level 1 % Level 1 # Level 2 % Level 2 # Level 3 % Level 3 # Level 4  \
# ...

# %%
clean1_df_Eth=Ethnicity_df[Ethnicity_df.Year==2019]

# %%
clean1_df_Eth
# Out:
#       District       Grade  Year Category  Number Tested Mean Scale Score  \
# 6            1           3  2019    Asian            146          614.151
# 13           1           4  2019    Asian            153          616.085
# 20           1           5  2019    Asian            142          613.317
# 27           1           6  2019    Asian            157          618.197
# 34           1           7  2019    Asian            163          619.528
# ...        ...         ...   ...      ...            ...              ...
# 6243        32           5  2019    White             17          586.118
# 6250        32           6  2019    White             33          607.121
# 6257        32           7  2019    White             24          602.583
# 6264        32           8  2019    White             21           606.19
# 6271        32  All Grades  2019    White            126          600.468
#
#      # Level 1 % Level 1 # Level 2 % Level 2 # Level 3 % Level 3 # Level 4  \
# ...

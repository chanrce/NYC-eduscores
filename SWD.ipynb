# %%
#Import dependencies
import pandas as pd

# %%
ELA_data = "2013-2019_ELA_Test_Results_District.xlsx"

SWD_df = pd.read_excel(ELA_data, 'SWD')

# %%
SWD_df
# Out:
#       District       Grade  Year Category  Number Tested  Mean Scale Score  \
# 0            1           3  2013  Not SWD            720        312.513886
# 1            1           3  2014  Not SWD            650        311.641541
# 2            1           3  2015  Not SWD            576        314.137146
# 3            1           3  2016  Not SWD            584        325.650696
# 4            1           3  2017  Not SWD            566        324.125427
# ...        ...         ...   ...      ...            ...               ...
# 3131        32  All Grades  2015      SWD           1350        261.284454
# 3132        32  All Grades  2016      SWD           1292        268.434204
# 3133        32  All Grades  2017      SWD           1268        269.122253
# 3134        32  All Grades  2018      SWD           1132        581.493835
# 3135        32  All Grades  2019      SWD           1087        579.173889
#
# ...

# %%
clean1_df_SWD=SWD_df[SWD_df.Year==2019]

# %%
clean1_df_SWD
# Out:
#       District       Grade  Year Category  Number Tested  Mean Scale Score  \
# 6            1           3  2019  Not SWD            549        610.976318
# 13           1           4  2019  Not SWD            536        609.705200
# 20           1           5  2019  Not SWD            520        609.834595
# 27           1           6  2019  Not SWD            521        611.264893
# 34           1           7  2019  Not SWD            547        614.930542
# ...        ...         ...   ...      ...            ...               ...
# 3107        32           5  2019      SWD            177        580.242920
# 3114        32           6  2019      SWD            217        576.511536
# 3121        32           7  2019      SWD            176        580.323853
# 3128        32           8  2019      SWD            192        582.401062
# 3135        32  All Grades  2019      SWD           1087        579.173889
#
# ...

# %%
#Import dependencies
import pandas as pd

# %%
ELA_data = "2013-2019_ELA_Test_Results_District.xlsx"

ELA_df = pd.read_excel(ELA_data)

# %%
ELA_df
# Out:
#       District       Grade  Year      Category  Number Tested  \
# 0            1           3  2013  All Students            877
# 1            1           3  2014  All Students            845
# 2            1           3  2015  All Students            750
# 3            1           3  2016  All Students            742
# 4            1           3  2017  All Students            721
# ...        ...         ...   ...           ...            ...
# 1563        32  All Grades  2015  All Students           6612
# 1564        32  All Grades  2016  All Students           6267
# 1565        32  All Grades  2017  All Students           5875
# 1566        32  All Grades  2018  All Students           5480
# 1567        32  All Grades  2019  All Students           5258
#
#       Mean Scale Score  # Level 1  % Level 1  # Level 2  % Level 2  # Level 3  \
# 0           303.476624        310  35.347778        266  30.330673        224
# ...

# %%
clean1_df=ELA_df[ELA_df.Year==2019]

# %%
clean1_df
# Out:
#       District       Grade  Year      Category  Number Tested  \
# 6            1           3  2019  All Students            675
# 13           1           4  2019  All Students            678
# 20           1           5  2019  All Students            694
# 27           1           6  2019  All Students            661
# 34           1           7  2019  All Students            720
# ...        ...         ...   ...           ...            ...
# 1539        32           5  2019  All Students            823
# 1546        32           6  2019  All Students           1009
# 1553        32           7  2019  All Students            927
# 1560        32           8  2019  All Students            997
# 1567        32  All Grades  2019  All Students           5258
#
#       Mean Scale Score  # Level 1  % Level 1  # Level 2  % Level 2  # Level 3  \
# 6           606.718506         54   8.000000        207  30.666666        288
# ...
